# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokhman07/MEDICAL_LLAVA_DATASET/blob/master/llama_log_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Gokhman07/MEDICAL_LLAVA_DATASET/refs/heads/master/LLAMA_3_2/logs_1_20_epochs.csv')

# %%
df
# Out:
#         loss  grad_norm  learning_rate  epoch
# 0     2.4401   4.549322         0.0002   0.03
# 1     2.2522   5.592897         0.0002   0.05
# 2     2.0207   8.451057         0.0002   0.07
# 3     1.8330   7.842957         0.0002   0.09
# 4     1.7000   5.768842         0.0002   0.10
# ...      ...        ...            ...    ...
# 1150  0.7240   9.366798         0.0002  19.91
# 1151  0.6713   8.451207         0.0002  19.93
# 1152  0.6882   8.867810         0.0002  19.95
# 1153  0.7010   8.353178         0.0002  19.97
# 1154  0.7489   8.308584         0.0002  19.98
#
# [1155 rows x 4 columns]

# %%
sns.set_style('darkgrid')

# %%
sns.lineplot(x='epoch', y='loss', data=df)
plt.rcParams["figure.figsize"] = (15, 10)  #
